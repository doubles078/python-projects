# %%
#Tapology scraper I made to gather all of the mma gyms in the US

import requests
import pandas as pd
import urllib
from bs4 import BeautifulSoup

#List of all the states to append to the URL
states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

state_dfs = []

#Go through all of the Tapology.com State list pages and take the data
for state in states:
    r=requests.get("http://www.tapology.com/gyms/state/"+state, verify=False)
    c=r.content

    soup=BeautifulSoup(c, "html.parser")
    all_gyms=soup.find_all("tr")

    l=[]
    counter = 0
    
    for gym in all_gyms:
        d={}
        rows = gym.find_all('td', {"class": "noBorder"})
        counter = 0
    
        for row in rows:
            if counter == 0:
                d["Name"] = row.text
                d["Link"] = row.find('a').get('href')
                counter += 1
            elif counter == 1:
                d["Location"] = row.text
                counter += 1
            elif counter == 2:
                d["Phone"] = row.text
                counter +=1
            else:
                try:
                    site = row.find('a')
                    d["Website"] = site.get('href')
                    counter = 0
                except:
                    d["Website"] = ""
                    counter = 0
        l.append(d)

    #List comprehension to remove all blank objects within our list
    l[:] = [x for x in l if x != {}]

    #Put it into a DataFrame for usage in a Jupyter Notebook
    df = pd.DataFrame(l)
    state_dfs.append(df)
# Out:
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
#Need to figure out why the 'for social' loop is not matching the strings.
import urllib3
urllib3.disable_warnings()

#Use the list of links scraped from the first pull to go into the detail pages for each gym and pull relevant information.
new_gyms = []

for gym in state_dfs:
    n=[]
    count = 0
    for index, row in gym.iterrows():
        new_r=requests.get("http://www.tapology.com"+row['Link'], verify=False)
        new_c=new_r.content

        new_soup=BeautifulSoup(new_c, "html.parser")
        new_all_gyms=new_soup.find_all("div", {"class": "details"})

        new_gyms.append(new_all_gyms)
        
        rows2 = new_gyms[index][0].find_all('a')
        
        socials = ['Facebook', 'Yelp', 'Twitter', 'Official Site']
        f={}
        gymname = new_soup.find_all("div", {"class": "pageHeading"})
        f['Gym'] = gymname[0].find('h1').text
        
        try:
            f['Logo'] = new_all_gyms[0].img['src']
        except:
            f['Logo'] = ''
        
        
        count += 1
        print(count)
        for row2 in rows2:
            if row2.text in socials:
                f[row2.text] = row2.get('href')
        
        n.append(f)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-228-a6202c8eac40> in <module>()
#      13         new_c=new_r.content
#      14
# ---> 15         new_soup=BeautifulSoup(new_c, "html.parser")
#      16         new_all_gyms=new_soup.find_all("div", {"class": "details"})
#      17
#
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     226             self.reset()
#     227             try:
# --> 228                 self._feed()
#     229                 break
#     230             except ParserRejectedMarkup:
#
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\bs4\__init__.py in _feed(self)
#     287         self.builder.reset()
#     288
# --> 289         self.builder.feed(self.markup)
#     290         # Close out any unfinished strings and close all the open tags.
#     291         self.endData()
#
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\bs4\builder\_htmlparser.py in feed(self, markup)
#     213         parser.soup = self.soup
#     214         try:
# --> 215             parser.feed(markup)
#     216         except HTMLParseError as e:
#     217             warnings.warn(RuntimeWarning(
#
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\html\parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\html\parser.py in goahead(self, end)
#     169             if startswith('<', i):
#     170                 if starttagopen.match(rawdata, i): # < + letter
# --> 171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
#     173                     k = self.parse_endtag(i)
#
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\html\parser.py in parse_starttag(self, i)
#     343             self.handle_startendtag(tag, attrs)
#     344         else:
# --> 345             self.handle_starttag(tag, attrs)
#     346             if tag in self.CDATA_CONTENT_ELEMENTS:
#     347                 self.set_cdata_mode(tag)
#
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\bs4\builder\_htmlparser.py in handle_starttag(self, name, attrs, handle_empty_element)
#      88             attrvalue = '""'
#      89         #print "START", name
# ---> 90         tag = self.soup.handle_starttag(name, None, None, attr_dict)
#      91         if tag and tag.is_empty_element and handle_empty_element:
#      92             # Unlike other parsers, html.parser doesn't send separate end tag
#
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\bs4\__init__.py in handle_starttag(self, name, namespace, nsprefix, attrs)
#     455
#     456         # print "Start tag %s: %s" % (name, attrs)
# --> 457         self.endData()
#     458
#     459         if (self.parse_only and len(self.tagStack) <= 1
#
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\bs4\__init__.py in endData(self, containerClass)
#     362                 return
#     363
# --> 364             o = containerClass(current_data)
#     365             self.object_was_parsed(o)
#     366
#
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\bs4\element.py in __new__(cls, value)
#     714         else:
#     715             u = str.__new__(cls, value, DEFAULT_OUTPUT_ENCODING)
# --> 716         u.setup()
#     717         return u
#     718
#
# c:\users\dan.donohue\appdata\local\programs\python\python36-32\lib\site-packages\bs4\element.py in setup(self, parent, previous_element, next_element, previous_sibling, next_sibling)
#     207         self.parent = parent
#     208
# --> 209         self.previous_element = previous_element
#     210         if previous_element is not None:
#     211             self.previous_element.next_element = self
#
# KeyboardInterrupt:

# %%
n[2]
# Out:
# {'Facebook': 'http://www.facebook.com/AuburnMixedMartialArts',
#  'Gym': 'Auburn Mixed Martial Arts',
#  'Logo': 'https://images.tapology.com/gyms/logos/341/profile/341-auburn-mma.jpg?1408756602',
#  'Official Site': 'http://www.auburnmma.com/'}

# %%
count = 0
for df in state_dfs:
    df.to_excel(writer,sheet_name=states[count], index=False)
    writer.save()
    count += 1
